# %% [markdown]
# # Add a new solvent or ion
#
# Use this notebook to add single-molecule PDB templates to `solvent_pdbs/` or `ion_pdbs/`. `LipidSystemBuilder` can place `Na` and `Cl` ions with an explicit `ion_count`, split between the top and bottom solvent layers.

# %%
from pathlib import Path

import numpy as np

from openff.toolkit import ForceField, Molecule, Topology
from openff.interchange import Interchange
from openff.units import unit

from lipidbuilder.utils import FORCEFIELD_DIR, ION_PDB_DIR, SOLVENT_PDB_DIR, resolve_force_field_path

SOLVENT_PDB_DIR.mkdir(parents=True, exist_ok=True)
ION_PDB_DIR.mkdir(parents=True, exist_ok=True)
