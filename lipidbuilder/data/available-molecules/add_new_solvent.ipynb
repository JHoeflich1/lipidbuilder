# %% [markdown]
# Note that this is not complete.
# # Add a new solvent
#
# Use this notebook to add single-molecule PDB templates to `solvent_pdbs/`. `LipidSystemBuilder` can neutralize charged systems with GROMACS `genion` after Packmol.

# %%
from pathlib import Path

import numpy as np

from openff.toolkit import ForceField, Molecule, Topology
from openff.interchange import Interchange
from openff.units import unit

from lipidbuilder.utils import FORCEFIELD_DIR, SOLVENT_PDB_DIR, resolve_force_field_path

SOLVENT_PDB_DIR.mkdir(parents=True, exist_ok=True)
SOLVENT_PDB_DIR.mkdir(parents=True, exist_ok=True)
